# %%
#########Importing libraries##########
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from PIL import  Image
import itertools
import warnings
warnings.filterwarnings("ignore")
import io

############Visualization#############
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff
######################################
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
########Bring in the DATA!###########

telcom = pd.read_csv("db/telemarker_db.csv")
telcom.head()
print(telcom.dtypes)
#######Data Cleaning Process#########

#Replacing spaces with null values in total charges column
telcom['TotalCharges'] = telcom["TotalCharges"].replace(" ",np.nan)
print("Percentage of null: " + str(round(telcom['TotalCharges'].isnull().sum()/telcom['TotalCharges'].count()*100,4))+"%")

#Dropping null values from total charges column which contain .16% missing data
telcom = telcom[telcom["TotalCharges"].notnull()]
telcom = telcom.reset_index()[telcom.columns]

#convert to float type
telcom["TotalCharges"] = telcom["TotalCharges"].astype(float)
telcom["MonthlyCharges"] = telcom["MonthlyCharges"].astype(float)

#replace 'No phone service' to No
telcom["MultipleLines"] = telcom["MultipleLines"].replace("No phone service","No")

#replace 'No internet service' to No for the following columns
replace_cols = [ 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                'TechSupport','StreamingTV', 'StreamingMovies']
for i in replace_cols : 
    telcom[i]  = telcom[i].replace({'No internet service' : 'No'})

#Change types of columns to boolean
YesNoColumns = ["Partner","Dependents","PhoneService","MultipleLines","OnlineSecurity",
                "OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies",
                "PaperlessBilling","Churn"]
for i in YesNoColumns :
    telcom[i]  = telcom[i].replace({'Yes':1,'No':0})
BoolColumns = YesNoColumns.copy()
BoolColumns.append("SeniorCitizen")
telcom[BoolColumns] = telcom[BoolColumns].astype('bool')
telcom
#Separating churn and non churn customers
# churn     = telcom[telcom["Churn"] == "Yes"]
# not_churn = telcom[telcom["Churn"] == "No"]

#     #Separating catagorical and numerical columns
# Id_col     = ['customerID']
# target_col = ["Churn"]
# cat_cols   = telcom.nunique()[telcom.nunique() < 6].keys().tolist()
# cat_cols   = [x for x in cat_cols if x not in target_col]
# num_cols   = [x for x in telcom.columns if x not in cat_cols + target_col + Id_col]
# Out:
# customerID           object
# gender               object
# City                 object
# State                object
# Phone                object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# Name                 object
# Address              object
# dtype: object
# Percentage of null: 0.1564%
#       customerID  gender       City State           Phone  SeniorCitizen  \
# 0     7590-VHVEG  Female  Sujzojpab    CA  (461) 230-8635          False
# 1     5575-GNVDE    Male     Bozuto    WY  (500) 288-7672          False
# 2     3668-QPYBK    Male   Cefzizof    NY  (368) 757-6896          False
# 3     7795-CFOCW    Male   Zavictej    NV  (865) 723-2538          False
# 4     9237-HQITU  Female    Socgimo    HI  (206) 668-9076          False
# 5     9305-CDSKC  Female   Japamber    VA  (854) 862-8556          False
# 6     1452-KIOVK    Male    Mejtoof    SD  (880) 500-3425          False
# 7     6713-OKOMC  Female   Bohbozlo    WI  (318) 983-2359          False
# 8     7892-POOKP  Female   Urtahfor    NC  (451) 608-9497          False
# 9     6388-TABGU    Male   Zuzusojo    MI  (659) 896-7415          False
# 10    9763-GRSKD    Male   Eketomef    CA  (304) 973-2275          False
# 11    7469-LKBCI    Male   Ofsifjid    MS  (739) 521-8349          False
# 12    8091-TTVAX    Male    Evmomos    IN  (949) 737-6715          False
# 13    0280-XJGEX    Male   Isukossi    VT  (271) 832-6353          False
# 14    5129-JLPIS    Male    Sutuveb    LA  (356) 316-1821          False
# 15    3655-SNQYZ  Female   Wegmegdo    IL  (876) 868-9463          False
# 16    8191-XWSZG  Female  Pahlegvub    NH  (734) 796-6958          False
# 17    9959-WOFKT    Male    Toanugo    ID  (535) 320-7645          False
# 18    4190-MFLUW  Female   Zeclifag    GA  (937) 856-8125          False
# 19    4183-MYFRB  Female    Nirozzo    AK  (716) 595-2319          False
# 20    8779-QRDMV    Male   Pesogbus    AL  (858) 930-8349           True
# 21    1680-VDCWW    Male    Ceundud    MD  (542) 963-9579          False
# 22    1066-JKSGK    Male   Neburoab    AL  (877) 209-2286          False
# 23    3638-WEABW  Female    Buvagal    AK  (484) 819-3247          False
# 24    6322-HRPFA    Male   Vorituda    DC  (432) 750-9808          False
# 25    6865-JZNKO  Female    Ponejap    UT  (522) 533-2326          False
# 26    6467-CHFZW    Male   Bicligpo    IN  (548) 273-4025          False
# 27    8665-UTDHZ    Male    Newikvu    TN  (674) 223-4141          False
# 28    5248-YGIJN    Male   Tocsepel    ME  (388) 708-8166          False
# 29    8773-HHUOZ  Female     Rihote    ID  (971) 660-5706          False
# ...          ...     ...        ...   ...             ...            ...
# 7002  1685-BQULA  Female     Owcawe    NM  (913) 901-7569          False
# 7003  9053-EJUNL    Male   Coroneeb    MN  (712) 201-2521          False
# 7004  0666-UXTJO    Male  Awekohcoz    AZ  (247) 585-2477           True
# 7005  1471-GIQKQ  Female    Tafuzgi    AZ  (210) 206-4134          False
# 7006  4807-IZYOZ  Female    Ravifmi    KY  (407) 936-3048          False
# 7007  1122-JWTJW    Male    Fosuidu    AL  (411) 572-2811          False
# 7008  9710-NJERN  Female    Zudolwo    OH  (963) 895-3081          False
# 7009  9837-FWLCH    Male     Keamni    MS  (529) 416-7363          False
# 7010  1699-HPSBG    Male   Ecoradse    OH  (828) 292-2039          False
# 7011  7203-OYKCT    Male   Kagjezub    NC  (883) 424-6866          False
# 7012  1035-IPQPU  Female   Pakuwhip    WA  (973) 722-8337           True
# 7013  7398-LXGYX    Male   Sugvirez    LA  (658) 265-5130          False
# 7014  2823-LKABH  Female   Uwawigev    OH  (518) 864-7014          False
# 7015  8775-CEBBJ  Female   Vazakora    FL  (616) 835-3816          False
# 7016  0550-DCXLH    Male     Behoki    WI  (269) 773-2390          False
# 7017  9281-CEDRU  Female    Agnomzu    NC  (405) 245-5735          False
# 7018  2235-DWLJU  Female  Usejamjif    KY  (968) 672-8331           True
# 7019  0871-OPBXW  Female   Arjuvmes    UT  (312) 621-6114          False
# 7020  3605-JISKB    Male   Uzwalroj    CO  (280) 494-7545           True
# 7021  6894-LFHLY    Male     Honeon    LA  (370) 388-9807           True
# 7022  9767-FFLEM    Male   Pupusjus    DE  (873) 777-7235          False
# 7023  0639-TSIQW  Female    Akmazte    MT  (352) 542-6557          False
# 7024  8456-QDAVC    Male    Rumfine    SC  (301) 988-1853          False
# 7025  7750-EYXWZ  Female   Sofetgec    TN  (748) 533-1093          False
# 7026  2569-WGERO  Female   Tajimere    MI  (831) 236-3565          False
# 7027  6840-RESVB    Male    Tipetha    VT  (555) 792-9026          False
# 7028  2234-XADUH  Female     Gilefi    ND  (838) 333-1739          False
# 7029  4801-JZAZL  Female   Gudatajo    WI  (813) 754-2366          False
# 7030  8361-LTMKD    Male   Tedciwze    NE  (687) 359-2037           True
# 7031  3186-AJIEK    Male   Cuzlioku    ME  (447) 346-5278          False
#
#       Partner  Dependents  tenure  PhoneService          ...           \
# 0        True       False       1         False          ...
# 1       False       False      34          True          ...
# 2       False       False       2          True          ...
# 3       False       False      45         False          ...
# 4       False       False       2          True          ...
# 5       False       False       8          True          ...
# 6       False        True      22          True          ...
# 7       False       False      10         False          ...
# 8        True       False      28          True          ...
# 9       False        True      62          True          ...
# 10       True        True      13          True          ...
# 11      False       False      16          True          ...
# 12       True       False      58          True          ...
# 13      False       False      49          True          ...
# 14      False       False      25          True          ...
# 15       True        True      69          True          ...
# 16      False       False      52          True          ...
# 17      False        True      71          True          ...
# 18       True        True      10          True          ...
# 19      False       False      21          True          ...
# 20      False       False       1         False          ...
# 21       True       False      12          True          ...
# 22      False       False       1          True          ...
# 23       True       False      58          True          ...
# 24       True        True      49          True          ...
# 25      False       False      30          True          ...
# 26       True        True      47          True          ...
# 27       True        True       1         False          ...
# 28       True       False      72          True          ...
# 29      False        True      17          True          ...
# ...       ...         ...     ...           ...          ...
# 7002    False       False      40          True          ...
# 7003    False       False      41          True          ...
# 7004     True       False      34          True          ...
# 7005    False       False       1          True          ...
# 7006    False       False      51          True          ...
# 7007     True        True       1          True          ...
# 7008    False       False      39          True          ...
# 7009     True        True      12          True          ...
# 7010    False       False      12          True          ...
# 7011    False       False      72          True          ...
# 7012     True       False      63          True          ...
# 7013     True       False      44          True          ...
# 7014    False       False      18          True          ...
# 7015    False       False       9          True          ...
# 7016    False       False      13          True          ...
# 7017     True       False      68          True          ...
# 7018    False       False       6         False          ...
# 7019    False       False       2          True          ...
# 7020     True       False      55          True          ...
# 7021    False       False       1          True          ...
# 7022    False       False      38          True          ...
# 7023    False       False      67          True          ...
# 7024    False       False      19          True          ...
# 7025    False       False      12         False          ...
# 7026    False       False      72          True          ...
# 7027     True        True      24          True          ...
# 7028     True        True      72          True          ...
# 7029     True        True      11         False          ...
# 7030     True       False       4          True          ...
# 7031    False       False      66          True          ...
#
#       StreamingTV StreamingMovies        Contract  PaperlessBilling  \
# 0           False           False  Month-to-month              True
# 1           False           False        One year             False
# 2           False           False  Month-to-month              True
# 3           False           False        One year             False
# 4           False           False  Month-to-month              True
# 5            True            True  Month-to-month              True
# 6            True           False  Month-to-month              True
# 7           False           False  Month-to-month             False
# 8            True            True  Month-to-month              True
# 9           False           False        One year             False
# 10          False           False  Month-to-month              True
# 11          False           False        Two year             False
# 12           True            True        One year             False
# 13           True            True  Month-to-month              True
# 14           True            True  Month-to-month              True
# 15           True            True        Two year             False
# 16          False           False        One year             False
# 17           True            True        Two year             False
# 18          False           False  Month-to-month             False
# 19          False            True  Month-to-month              True
# 20          False            True  Month-to-month              True
# 21          False           False        One year             False
# 22          False           False  Month-to-month             False
# 23          False           False        Two year              True
# 24          False           False  Month-to-month             False
# 25          False           False  Month-to-month              True
# 26           True            True  Month-to-month              True
# 27          False           False  Month-to-month             False
# 28           True            True        Two year              True
# 29           True            True  Month-to-month              True
# ...           ...             ...             ...               ...
# 7002         True           False  Month-to-month              True
# 7003         True           False  Month-to-month              True
# 7004         True           False  Month-to-month              True
# 7005        False           False  Month-to-month             False
# 7006        False           False        Two year             False
# 7007        False           False  Month-to-month              True
# 7008        False           False        Two year             False
# 7009        False           False  Month-to-month              True
# 7010         True           False        One year              True
# 7011         True            True        One year              True
# 7012         True            True  Month-to-month              True
# 7013        False           False  Month-to-month              True
# 7014        False            True  Month-to-month              True
# 7015        False           False  Month-to-month              True
# 7016         True            True  Month-to-month             False
# 7017         True           False        Two year             False
# 7018         True            True  Month-to-month              True
# 7019        False           False  Month-to-month              True
# 7020        False           False        One year             False
# 7021        False           False  Month-to-month              True
# 7022        False           False  Month-to-month              True
# 7023         True           False  Month-to-month              True
# 7024         True           False  Month-to-month              True
# 7025         True            True        One year             False
# 7026        False           False        Two year              True
# 7027         True            True        One year              True
# 7028         True            True        One year              True
# 7029        False           False  Month-to-month              True
# 7030        False           False  Month-to-month              True
# 7031         True            True        Two year              True
#
#                   PaymentMethod  MonthlyCharges  TotalCharges  Churn  \
# 0              Electronic check           29.85         29.85  False
# 1                  Mailed check           56.95       1889.50  False
# 2                  Mailed check           53.85        108.15   True
# 3     Bank transfer (automatic)           42.30       1840.75  False
# 4              Electronic check           70.70        151.65   True
# 5              Electronic check           99.65        820.50   True
# 6       Credit card (automatic)           89.10       1949.40  False
# 7                  Mailed check           29.75        301.90  False
# 8              Electronic check          104.80       3046.05   True
# 9     Bank transfer (automatic)           56.15       3487.95  False
# 10                 Mailed check           49.95        587.45  False
# 11      Credit card (automatic)           18.95        326.80  False
# 12      Credit card (automatic)          100.35       5681.10  False
# 13    Bank transfer (automatic)          103.70       5036.30   True
# 14             Electronic check          105.50       2686.05  False
# 15      Credit card (automatic)          113.25       7895.15  False
# 16                 Mailed check           20.65       1022.95  False
# 17    Bank transfer (automatic)          106.70       7382.25  False
# 18      Credit card (automatic)           55.20        528.35   True
# 19             Electronic check           90.05       1862.90  False
# 20             Electronic check           39.65         39.65   True
# 21    Bank transfer (automatic)           19.80        202.25  False
# 22                 Mailed check           20.15         20.15   True
# 23      Credit card (automatic)           59.90       3505.10  False
# 24      Credit card (automatic)           59.60       2970.30  False
# 25    Bank transfer (automatic)           55.30       1530.60  False
# 26             Electronic check           99.35       4749.15   True
# 27             Electronic check           30.20         30.20   True
# 28      Credit card (automatic)           90.25       6369.45  False
# 29                 Mailed check           64.70       1093.10   True
# ...                         ...             ...           ...    ...
# 7002  Bank transfer (automatic)           93.40       3756.40  False
# 7003           Electronic check           89.20       3645.75  False
# 7004    Credit card (automatic)           85.20       2874.45  False
# 7005           Electronic check           49.95         49.95  False
# 7006  Bank transfer (automatic)           20.65       1020.75  False
# 7007               Mailed check           70.65         70.65   True
# 7008               Mailed check           20.15        826.00  False
# 7009           Electronic check           19.20        239.00  False
# 7010           Electronic check           59.80        727.80   True
# 7011           Electronic check          104.95       7544.30  False
# 7012           Electronic check          103.50       6479.40  False
# 7013    Credit card (automatic)           84.80       3626.35  False
# 7014  Bank transfer (automatic)           95.05       1679.40  False
# 7015  Bank transfer (automatic)           44.20        403.35   True
# 7016               Mailed check           73.35        931.55  False
# 7017  Bank transfer (automatic)           64.10       4326.25  False
# 7018           Electronic check           44.40        263.05  False
# 7019               Mailed check           20.05         39.25  False
# 7020    Credit card (automatic)           60.00       3316.10  False
# 7021           Electronic check           75.75         75.75   True
# 7022    Credit card (automatic)           69.50       2625.25  False
# 7023    Credit card (automatic)          102.95       6886.25   True
# 7024  Bank transfer (automatic)           78.70       1495.10  False
# 7025           Electronic check           60.65        743.30  False
# 7026  Bank transfer (automatic)           21.15       1419.40  False
# 7027               Mailed check           84.80       1990.50  False
# 7028    Credit card (automatic)          103.20       7362.90  False
# 7029           Electronic check           29.60        346.45  False
# 7030               Mailed check           74.40        306.60   True
# 7031  Bank transfer (automatic)          105.65       6844.50  False
#
#                     Name               Address
# 0       Margaret Gregory        1927 Gusta Way
# 1           Allie Valdez        525 Ahev Grove
# 2         Bertha Padilla  985 Utomez Extension
# 3              Ian Perez    1030 Gagicu Avenue
# 4         Gilbert Murray       1905 Ukiij Path
# 5          Hunter Powers       1019 Tunzu Pike
# 6         Sallie Wheeler     1988 Vutiko Ridge
# 7       Charles Sandoval      1471 Kapad Trail
# 8          Birdie Bryant      1620 Vagih Point
# 9         Elmer McKinney       1187 Obase Pass
# 10       Justin Marshall   723 Sintih Junction
# 11            Betty Vega      1367 Basga Point
# 12      Eleanor Gonzalez       122 Helsif Path
# 13            Alta Bryan     1499 Mohpe Center
# 14           Carrie Wood   1987 Iceap Junction
# 15              Eva Dean   1764 Cewbak Parkway
# 16         Patrick Ramos        405 Momij Road
# 17           Clara Marsh  1407 Zerhe Boulevard
# 18             Kyle Cruz  1225 Fecce Boulevard
# 19         Susan Hawkins   1755 Izrad Turnpike
# 20          Kate Delgado     1537 Lagjor Ridge
# 21       Chester Manning      385 Vater Street
# 22       Hattie McDonald    1928 Fuuk Junction
# 23         Marie Barrett      831 Livij Center
# 24    Alejandro Harrison    581 Vicez Turnpike
# 25      Mathilda Ballard    1127 Sobu Turnpike
# 26      Francisco Mathis         251 Vijep Way
# 27     Elizabeth Morales     1325 Sukcej Plaza
# 28          Elijah Lynch      1458 Bufji Point
# 29        Rachel Stewart    1649 Bapfa Highway
# ...                  ...                   ...
# 7002        Gene Jimenez    909 Buvi Extension
# 7003         May Summers        528 Utho Manor
# 7004         Lida Porter         973 Toto Loop
# 7005      Delia McKenzie       854 Igino Plaza
# 7006        Rhoda Wagner         816 Ubbah Way
# 7007       Rebecca Quinn       1063 Huud Grove
# 7008         Adele Lopez       475 Bezi Circle
# 7009        Mattie Munoz    1023 Lurju Parkway
# 7010         Eliza Hayes        110 Geca Manor
# 7011    Cynthia Roberson      1373 Mici Square
# 7012    Lester Armstrong         736 Jimo View
# 7013        Nelle Foster        1959 Ebva Lane
# 7014     Kathryn Spencer       1522 Hazli Loop
# 7015      Adele Copeland    1862 Iteof Terrace
# 7016        Terry Thomas     1152 Teldo Center
# 7017         Gerald Cole     1103 Gipbur Court
# 7018       Stanley Allen       146 Ufeole Road
# 7019          Troy Drake     1047 Cesad Avenue
# 7020    Cordelia Summers     1447 Velja Center
# 7021            Leo Reid        412 Fuzaj Loop
# 7022        Hallie Terry     683 Datot Parkway
# 7023          Roger Cain       999 Faur Center
# 7024      Theresa Rivera     1485 Kufi Heights
# 7025    Lucille Matthews      998 Vizvak Ridge
# 7026    Isabelle Baldwin       1668 Wejli Pike
# 7027        Hannah White  952 Tagrun Extension
# 7028       Elijah Reeves      45 Zomit Parkway
# 7029       Marvin Curtis      1513 Apiat Court
# 7030    Jeanette Hopkins     800 Husoz Parkway
# 7031      Clyde McDaniel      186 Jolon Square
#
# [7032 rows x 26 columns]

# %%
#labels
lab = telcom["Churn"].value_counts().keys().tolist()
#values
val = telcom["Churn"].value_counts().values.tolist()

trace = go.Pie(labels = lab ,
               values = val ,
               marker = dict(colors =  [ 'royalblue' ,'lime'],
                             line = dict(color = "white",
                                         width =  1.3)
                            ),
               rotation = 90,
               hoverinfo = "label+value+text",
               hole = .5
              )
layout = go.Layout(dict(title = "Customer attrition in data",
                        plot_bgcolor  = "rgb(243,243,243)",
                        paper_bgcolor = "rgb(243,243,243)",
                       )
                  )

data = [trace]
fig = go.Figure(data = data,layout = layout)
py.iplot(fig)
# Out:
# <div id="1b49bb5b-ae2e-41c5-aa5b-e32d1a40a3d7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1b49bb5b-ae2e-41c5-aa5b-e32d1a40a3d7", [{"hole": 0.5, "hoverinfo": "label+value+text", "labels": [false, true], "marker": {"colors": ["royalblue", "lime"], "line": {"color": "white", "width": 1.3}}, "rotation": 90, "values": [5163, 1869], "type": "pie", "uid": "8fff29d2-d573-11e8-880c-8c859026d06c"}], {"paper_bgcolor": "rgb(243,243,243)", "plot_bgcolor": "rgb(243,243,243)", "title": "Customer attrition in data"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
